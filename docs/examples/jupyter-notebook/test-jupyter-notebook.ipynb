# %%
from IPython.display import IFrame
IFrame(src='https://crescent-stdio.github.io/wave-roll/', width='100%', height='800px')
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://crescent-stdio.github.io/wave-roll/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
